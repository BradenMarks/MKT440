# %%
import seaborn as sns
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/chiharuishida/Tutorialdata/main/ad_dataset_withheaders.csv"
df = pd.read_csv(url)

# %%
df.head(10)
# Out:
#    Site_Time  Age  DailyTime  Gender AdClicking
# 0      68.95   35     256.09  Female         No
# 1      80.23   31     193.77    Male         No
# 2      69.47   26     236.50  Female         No
# 3      74.15   29     245.89    Male         No
# 4      68.37   35     225.58  Female         No
# 5      59.99   23     226.74    Male         No
# 6      88.91   33     208.36  Female         No
# 7      66.00   48     131.76    Male        Yes
# 8      74.53   30     221.51    Male         No
# 9      69.88   20     183.82    Male         No

# %%
df.describe()
# Out:
#          Site_Time          Age    DailyTime
# count  1000.000000  1000.000000  1000.000000
# mean     65.000200    36.009000   180.000100
# std      15.853615     8.785562    43.902339
# min      32.600000    19.000000   104.780000
# 25%      51.360000    29.000000   138.830000
# 50%      68.215000    35.000000   183.130000
# 75%      78.547500    42.000000   218.792500
# max      91.430000    61.000000   269.960000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Site_Time   1000 non-null   float64
#  1   Age         1000 non-null   int64
#  2   DailyTime   1000 non-null   float64
#  3   Gender      1000 non-null   object
#  4   AdClicking  1000 non-null   object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 39.2+ KB

# %%
df['Gender'].value_counts()
# Out:
# Female    519
# Male      481
# Name: Gender, dtype: int64

# %%
df.corr()
# Out:
# <ipython-input-8-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#            Site_Time       Age  DailyTime
# Site_Time   1.000000 -0.331513   0.518658
# Age        -0.331513  1.000000  -0.367209
# DailyTime   0.518658 -0.367209   1.000000

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <ipython-input-10-6dc1c4c1753e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)
# <Axes: >

# %%
sns.heatmap(df.corr(), cmap="YlGnBu")
# Out:
# <ipython-input-11-9ee46710bf8b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), cmap="YlGnBu")
# <Axes: >

# %%
sns.pairplot(df)

# %%
sns.scatterplot(x="Age", y="DailyTime", data=df)
# Out:
# <Axes: xlabel='Age', ylabel='DailyTime'>

# %%
sns.lmplot(x = "Age", y = "DailyTime", data = df)

# %%
sns.scatterplot(x="Age", y="DailyTime", hue="AdClicking", data=df)
# Out:
# <Axes: xlabel='Age', ylabel='DailyTime'>

# %%
sns.lmplot(x = "Age", y = "DailyTime", hue="AdClicking", data = df)

# %%
sns.countplot(x='Gender', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x='Gender', data=df, color='b')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df_Gender=df.groupby("Gender")
df_Gender.mean()
# Out:
# <ipython-input-29-31ac3f095f1e>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_Gender.mean()
#         Site_Time        Age   DailyTime
# Gender
# Female  65.289287  36.186898  178.816763
# Male    64.688274  35.817048  181.276923

# %%
sns.boxplot(x="Gender", y="Site_Time", data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Site_Time'>

# %%
sns.boxplot(x="Gender", y="Site_Time", hue="AdClicking", data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Site_Time'>

# %%
df_top3_SiteTime = df.nlargest(3, "Site_Time")
df_top3_SiteTime
# Out:
#      Site_Time  Age  DailyTime  Gender AdClicking
# 533      91.43   39     209.91    Male         No
# 860      91.37   45     182.65    Male        Yes
# 927      91.15   38     184.98  Female         No
